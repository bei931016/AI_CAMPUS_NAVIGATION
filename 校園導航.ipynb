# %%
campus = {
    "圖書館": {
        "介紹": "提供借書、自習及討論空間"
    },
    "行政大樓": {
        "介紹": "文書組、出納組、總務處"
    },
    "行政二館": {
        "介紹": "教務處、註冊組、課務組"
    },
     "資訊大樓": {
        "介紹": "上課教室"
    },
     "電機一管": {
        "介紹": "上課教室"
    },
     "電機二館": {
        "介紹": "上課教室"
    },
    "電機三館": {
        "介紹": "上課教室"
    },
    "管理學院": {
        "介紹": "上課教室"
    },
    "明明樓": {
        "介紹": "上課教室"
    },
    "半材館": {
        "介紹": "上課教室"
    },
    "機械大樓": {
        "介紹": "上課教室"
    },
    "土木館": {
        "介紹": "上課教室"
    },
    "明學樓": {
        "介紹": "上課教室"
    },
    "電子館": {
        "介紹": "上課教室"
    },
    "明光樓": {
        "介紹": "生活輔導組、上課教室"
    },
    "逢喜樓": {
        "介紹": "上課教室"
    },
    "立緒樓": {
        "介紹": "保齡球館、上課教室"
    },
    "體育館": {
        "介紹": "校安中心、體育室"
    },
    "鴻超樓": {
        "介紹": "上課教室"
    },
    "宗山樓": {
        "介紹": "健康中心、住宿服務組、學生餐廳"
    },
    "體安樓": {
        "介紹": "宿舍"
    },
    "明新學苑": {
        "介紹": "宿舍"
    },
    "愛苑": {
        "介紹": "宿舍"
    },
    "忠苑": {
        "介紹": "宿舍"
    },
    "孝苑": {
        "介紹": "宿舍"
    },
    "仁苑": {
        "介紹": "宿舍"
    },
    "信苑": {
        "介紹": "宿舍"
    },
    "棒球場": {
        "介紹": "打棒球"
    },
}


place = input("請輸入想去的地點：")


if place in campus:
    print("找到地點！")
    print("地點：", place)
    print("介紹：", campus[place]["介紹"])
else:
    print("查無此地點")
# Out:
# 請輸入想去的地點：棒球場
# 找到地點！
# 地點： 棒球場
# 介紹： 打棒球

# %%
import webbrowser

# 校園地點資料
campus = {
    "圖書館": {
        "介紹": "提供借書、自習及討論空間",
        "地圖": "https://maps.app.goo.gl/CscY76Tjk2AtnzyM8"
    },
    "行政大樓": {
        "介紹": "文書組、出納組、總務處",
        "地圖": "https://maps.app.goo.gl/5FhhVpwHYibnEMF28"
    },
    "行政二館": {
        "介紹": "教務處、註冊組、課務組",
        "地圖": "https://maps.app.goo.gl/ygmQjtuSzGeSQ7F97"
    },
     "資訊大樓": {
        "介紹": "上課教室",
        "地圖": "https://maps.app.goo.gl/y4cNQimapsnVKGw58"
    },
     "電機管": {
        "介紹": "上課教室",
        "地圖": "https://maps.app.goo.gl/DFVG5rxJfpUoUNLK8"
    },
    "管理學院": {
        "介紹": "上課教室",
        "地圖": "https://maps.app.goo.gl/P9QPnxe9Nan4zVoP7"
    },
    "明明樓": {
        "介紹": "上課教室",
        "地圖": "https://maps.app.goo.gl/VGtHCizswnuWpn9y5"
    },
    "半材館": {
        "介紹": "上課教室",
        "地圖": "https://maps.app.goo.gl/7VTHbpWNfxeMvFqu9"
    },
    "明學樓": {
        "介紹": "上課教室",
        "地圖": "https://maps.app.goo.gl/sjT3ect2BUw8k6TBA"
    },
    "土木館": {
        "介紹": "上課教室",
        "地圖": "https://maps.app.goo.gl/vxt5Espt8AmHmjtT6"
    },
    "電子館": {
        "介紹": "上課教室",
        "地圖": "https://maps.app.goo.gl/gjXdN5LtxetJLDQF9"
    },
    "明光樓": {
        "介紹": "生活輔導組、上課教室",
        "地圖": "https://maps.app.goo.gl/hm19iXEzvADgsEWK8"
    },
    "逢喜樓": {
        "介紹": "上課教室",
        "地圖": "https://maps.app.goo.gl/2GYcPAcE3VNPiRR67"
    },
    "立緒樓": {
        "介紹": "保齡球館、上課教室",
        "地圖": "https://maps.app.goo.gl/3BBLbpNTCTMZejkD8"
    },
    "體育館": {
        "介紹": "校安中心、體育室",
        "地圖": "https://maps.app.goo.gl/17VqchUdfxjpXvEr7"
    },
    "鴻超樓": {
        "介紹": "上課教室",
        "地圖": "https://maps.app.goo.gl/5jXddjCDhf3RKPu76"
    },
    "宗山樓": {
        "介紹": "健康中心、住宿服務組、學生餐廳",
        "地圖": "https://maps.app.goo.gl/17VqchUdfxjpXvEr7"
    },
    "體安樓": {
        "介紹": "宿舍",
        "地圖": "https://maps.app.goo.gl/DNqwLPMFKgTY53pj6"
    },
    "明新學苑": {
        "介紹": "宿舍",
        "地圖": "https://maps.app.goo.gl/dPP6o2gi6vF7FgRk6"
    },
    "愛苑": {
        "介紹": "宿舍",
        "地圖": "https://maps.app.goo.gl/PnYA61cxGvpSU9fW8"
    },
    "忠苑": {
        "介紹": "宿舍",
        "地圖": "https://maps.app.goo.gl/i61jdyJxFq8hSdjC6"
    },
    "孝苑": {
        "介紹": "宿舍",
        "地圖": "https://maps.app.goo.gl/i61jdyJxFq8hSdjC6"
    },
    "仁苑": {
        "介紹": "宿舍",
        "地圖": "https://maps.app.goo.gl/9AqYw6ZkSnDR5Daq5"
    },
    "信苑": {
        "介紹": "宿舍",
        "地圖": "https://maps.app.goo.gl/FS3Naw2tiFnXQQMK8"
    },
    "棒球場": {
        "介紹": "打棒球",
        "地圖": "https://maps.app.goo.gl/CFy9TzLWbbuMZHCv5"
    },

}

# 使用者輸入
place = input("請輸入想去的地點：")

# 查詢
if place in campus:
    print("\n找到地點！")
    print("地點：", place)
    print("介紹：", campus[place]["介紹"])

    print("\nGoogle Maps：")
    print(campus[place]["地圖"])

else:
    print("查無此地點")
# Out:
# 請輸入想去的地點：棒球場
#
# 找到地點！
# 地點： 棒球場
# 介紹： 打棒球
#
# Google Maps：
# https://maps.app.goo.gl/CFy9TzLWbbuMZHCv5

# %%
place = input("請輸入想查詢的地點：")

if place in campus:
    print("==========")
    print("地點：", place)
    print("介紹：", campus[place]["介紹"])
    print("Google Maps：")
    print(campus[place]["地圖"])
else:
    print("❌ 查無此地點")
# Out:
# 請輸入想查詢的地點：棒球場
# ...
# 地點： 棒球場
# 介紹： 打棒球
# Google Maps：
# https://maps.app.goo.gl/CFy9TzLWbbuMZHCv5

# %%
question = input("請輸入你的需求：")

if "借書" in question or "讀書" in question or "自習" in question or "還書" in question:
    place = "圖書館"

elif "吃飯" in question or "餐廳" in question or "肚子餓" in question or "健康中心" in question:
    place = "宗山樓"

elif "教務" in question or "選課" in question or "註冊" in question:
    place = "行政二館"

elif "文書" in question or "總務" in question:
    place = "行政大樓"

elif "運動" in question or "打球" in question:
    place = "體育館"

else:
    place = None

if place:
    print("\nAI 推薦結果")
    print("----------------------")
    print("推薦地點：", place)
    print("介紹：", campus[place]["介紹"])
    print("Google Maps：")
    print(campus[place]["地圖"])
else:
    print("找不到符合的地點")
# Out:
# 請輸入你的需求：健康中心
#
# AI 推薦結果
# ----------------------
# 推薦地點： 宗山樓
# 介紹： 健康中心、住宿服務組、學生餐廳
# Google Maps：
# https://maps.app.goo.gl/17VqchUdfxjpXvEr7

# %%
while True:

    print("\n========== AI 校園導航系統 ==========")
    print("1. 查詢建築物")
    print("2. AI 推薦地點")
    print("3. 離開")

    choice = input("請輸入功能(1~3)：")


    if choice == "1":

        place = input("請輸入建築名稱：")

        if place in campus:
            print("\n查詢結果")
            print("----------------------")
            print("地點：", place)
            print("介紹：", campus[place]["介紹"])
            print("Google Maps：")
            print(campus[place]["地圖"])

        else:
            print("❌ 查無此建築")


    elif choice == "2":

        question = input("請輸入你的需求：")

        if "借書" in question or "讀書" in question or "還書" in question:
            place = "圖書館"

        elif "吃飯" in question or "餐廳" in question or "健康中心" in question:
            place = "宗山樓"

        elif "選課" in question or "教務" in question:
            place = "行政二館"

        elif "總務" in question:
            place = "行政大樓"

        elif "運動" in question:
            place = "體育館"

        else:
            place = None

        if place:
            print("\nAI 推薦結果")
            print("----------------------")
            print("推薦地點：", place)
            print("介紹：", campus[place]["介紹"])
            print("Google Maps：")
            print(campus[place]["地圖"])

        else:
            print("找不到適合的地點")


    elif choice == "3":
        print("感謝使用 AI 校園導航系統！")
        break

    else:
        print("請輸入 1~3")
# Out:
# ========== AI 校園導航系統 ==========
# 1. 查詢建築物
# 2. AI 推薦地點
# 3. 離開
# 請輸入功能(1~3)：1
# 請輸入建築名稱：管理學院
#
# 查詢結果
# ----------------------
# 地點： 管理學院
# 介紹： 上課教室
# Google Maps：
# https://maps.app.goo.gl/P9QPnxe9Nan4zVoP7
#
# ========== AI 校園導航系統 ==========
# 1. 查詢建築物
# 2. AI 推薦地點
# 3. 離開
# 請輸入功能(1~3)：2
# 請輸入你的需求：吃飯
#
# AI 推薦結果
# ----------------------
# 推薦地點： 宗山樓
# 介紹： 健康中心、住宿服務組、學生餐廳
# Google Maps：
# https://maps.app.goo.gl/17VqchUdfxjpXvEr7
#
# ========== AI 校園導航系統 ==========
# 1. 查詢建築物
# 2. AI 推薦地點
# 3. 離開
# 請輸入功能(1~3)：3
# 感謝使用 AI 校園導航系統！
